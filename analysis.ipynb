# %% [markdown]
# # Introduction
# ## Determining  New Market for Space-borne  data.

# %% [markdown]
# Step 1 : Data Loading

# %%
# Import necessary libraries
import pandas as pd              # For data manipulation and analysis
import numpy as np               # For numerical operations
import matplotlib.pyplot as plt # For data visualization
import seaborn as sns           # For enhanced data visualization

get_ipython().system('pip list')
# Out:
# Package           Version
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ----------------- ------------
# asttokens         2.4.0
# backcall          0.2.0
# colorama          0.4.6
# comm              0.1.4
# contourpy         1.1.1
# cycler            0.11.0
# debugpy           1.8.0
# decorator         5.1.1
# exceptiongroup    1.1.3
# executing         1.2.0
# fonttools         4.42.1
# ipykernel         6.25.2
# ipython           8.15.0
# jedi              0.19.0
# jupyter_client    8.3.1
# jupyter_core      5.3.1
# kiwisolver        1.4.5
# matplotlib        3.8.0
# matplotlib-inline 0.1.6
# nest-asyncio      1.5.8
# numpy             1.26.0
# packaging         23.1
# pandas            2.1.1
# parso             0.8.3
# pickleshare       0.7.5
# Pillow            10.0.1
# pip               23.1.2
# platformdirs      3.10.0
# prompt-toolkit    3.0.39
# psutil            5.9.5
# ...

# %% [markdown]
# loading dataset into dataframe

# %%
# Import necessary libraries
import pandas as pd

# Load your dataset into a Pandas DataFrame
df = pd.read_csv('./Space Data Clean.csv')

# Display the first few rows of the DataFrame to verify the data loading
df.head()
# Out:
#                   Company Name  \
# 0                       SpaceX
# 1                       OneWeb
# 2  Spirit AeroSystems Holdings
# 3                          SES
# 4                  Blue Origin
#
#                                            Verticals  \
# 0       Industrials, Manufacturing, Space Technology
# 1                              Space Technology, TMT
# 2  Industrials, Manufacturing, Space Technology, TMT
# 3                              Space Technology, TMT
# 4                 Industrials, Space Technology, TMT
#
#                                             Keywords Company Financing Status  \
# 0  satellite development, space launch, space lau...   Venture Capital-Backed
# 1  broadband access, broadband satellite, interne...    Private Equity-Backed
# 2  aerostructures, aircraft parts, defense struct...       Formerly PE-Backed
# 3  artificial satellite, geostationary satellite,...       Formerly VC-backed
# ...

# %% [markdown]
# # Step 2 : Explolatory Data Analysis

# %%
# Display basic information about the dataset
print("Basic Dataset Information:")
print("Number of rows and columns:", df.shape)


# Check for missing data
missing_data = df.isnull().sum()
print("\nMissing data counts:\n", missing_data)
# Out:
# Basic Dataset Information:
# Number of rows and columns: (326, 39)
#
# Missing data counts:
#  Company Name                     0
# Verticals                        0
# Keywords                         0
# Company Financing Status         0
# Total Raised                   151
# Business Status                  9
# Ownership Status                 0
# Universe                         0
# Employees                      103
# Exchange                       311
# Ticker                         311
# Year Founded                    20
# HQ Location                      1
# HQ City                          3
# HQ State/Province               19
# HQ Country                       1
# HQ Global Region                 1
# HQ Global Sub Region             1
# # Active Investors             119
# Acquirers                      267
# First Financing Date            28
# First Financing Size           158
# First Financing Valuation      271
# First Financing Deal Type        0
# ...

# %% [markdown]
# # Step 3: Data Cleaning and Preprocessing
#
# Clean the data by handling missing values, duplicates, and outliers.
# Perform any necessary data transformations (e.g., data type conversions, date parsing).
# Create new features if needed.

# %%
# Step 1: Remove Missing Values
df.dropna(inplace=True)
# Check for missing data
missing_data_cleaned = df.isnull().sum()
print("\nMissing data counts after cleaning:\n", missing_data_cleaned)
# Out:
# Missing data counts after cleaning:
#  Company Name                   0
# Verticals                      0
# Keywords                       0
# Company Financing Status       0
# Total Raised                   0
# Business Status                0
# Ownership Status               0
# Universe                       0
# Employees                      0
# Exchange                       0
# Ticker                         0
# Year Founded                   0
# HQ Location                    0
# HQ City                        0
# HQ State/Province              0
# HQ Country                     0
# HQ Global Region               0
# HQ Global Sub Region           0
# # Active Investors             0
# Acquirers                      0
# First Financing Date           0
# First Financing Size           0
# First Financing Valuation      0
# First Financing Deal Type      0
# First Financing Deal Type 2    0
# First Financing Deal Class     0
# First Financing Status         0
# ...

# %%
# Save the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_dataset.csv', index=False)


# Load the cleaned dataset from the saved CSV file
cleaned_df = pd.read_csv('./Space Data Clean.csv')

# Display the number of rows and columns in the cleaned DataFrame
num_rows, num_cols = cleaned_df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")

# Display the first 5 rows of the cleaned DataFrame
print("\nFirst 5 rows of the cleaned DataFrame:")
print(cleaned_df.head())
# Out:
# Number of rows: 326
# Number of columns: 39
#
# First 5 rows of the cleaned DataFrame:
#                   Company Name  \
# 0                       SpaceX
# 1                       OneWeb
# 2  Spirit AeroSystems Holdings
# 3                          SES
# 4                  Blue Origin
#
#                                            Verticals  \
# 0       Industrials, Manufacturing, Space Technology
# 1                              Space Technology, TMT
# 2  Industrials, Manufacturing, Space Technology, TMT
# 3                              Space Technology, TMT
# 4                 Industrials, Space Technology, TMT
#
#                                             Keywords Company Financing Status  \
# 0  satellite development, space launch, space lau...   Venture Capital-Backed
# 1  broadband access, broadband satellite, interne...    Private Equity-Backed
# 2  aerostructures, aircraft parts, defense struct...       Formerly PE-Backed
# ...

# %% [markdown]
# # Step 4 : EDA

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset into a Pandas DataFrame
df = pd.read_csv('./Space Data Clean.csv')


# 4. Scatter plot to explore relationships between two numerical columns (e.g., Total Raised vs. Year Founded)
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Year Founded', y='Total Raised')
plt.xlabel('Year Founded')
plt.ylabel('Total Raised')
plt.title('Total Raised vs. Year Founded')
plt.show()
# Out:
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Group the data by the 'Year Founded' column and count the number of companies founded each year
companies_founded_by_year = df['Year Founded'].value_counts().sort_index()

# Create a line plot to visualize the number of companies founded each year
plt.figure(figsize=(12, 6))
plt.plot(companies_founded_by_year.index, companies_founded_by_year.values, marker='o', linestyle='-')
plt.xlabel('Year Founded')
plt.ylabel('Number of Companies Founded')
plt.title('Number of Companies Founded Each Year')
plt.grid(True)
plt.show()

# %%
# Count the number of companies in each vertical
vertical_counts = df['Verticals'].value_counts()

# Create a bar plot to visualize the distribution of companies across verticals
plt.figure(figsize=(24, 40))
sns.barplot(x=vertical_counts.values, y=vertical_counts.index, palette='viridis')
plt.xlabel('Number of Companies')
plt.ylabel('Verticals')
plt.title('Distribution of Companies Across Verticals')
plt.show()
# Out:
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Import necessary libraries
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns  # Make sure you've imported seaborn

# Split the 'Verticals' column by commas and flatten the resulting list of words
verticals_words = [word.strip() for words in df['Verticals'].str.split(',') for word in words]

# Count the occurrences of each word
word_counts = Counter(verticals_words)

# Create a DataFrame from the word counts
word_counts_df = pd.DataFrame.from_dict(word_counts, orient='index', columns=['Count'])
word_counts_df = word_counts_df.reset_index().rename(columns={'index': 'Word'})

# Sort the DataFrame by count in descending order
word_counts_df = word_counts_df.sort_values(by='Count', ascending=False)

# Display the top 10 most common words and their counts
top_10_words = word_counts_df.head(20)
print("Top 10 Most Common Words:")
print(top_10_words)

# Create a bar plot to visualize the most common words
plt.figure(figsize=(12, 6))
sns.barplot(x='Count', y='Word', data=top_10_words, palette='viridis')
plt.xlabel('Count')
plt.ylabel('Word')
plt.title('Top 10 Consumers of Space-borne Data')
plt.show()
# Out:
# Top 10 Most Common Words:
#                                           Word  Count
# 2                             Space Technology    326
# 3                                          TMT    228
# 0                                  Industrials    145
# 1                                Manufacturing     88
# 7                          Robotics and Drones     21
# 8                                     Big Data     19
# 9                                         SaaS     14
# 12  Artificial Intelligence & Machine Learning     14
# 6                                    CleanTech     12
# 14                                      Mobile     10
# 15                          Internet of Things     10
# 4                                    Oil & Gas      6
# 5                                Mobility Tech      6
# 17                                      AgTech      5
# 16                              Nanotechnology      4
# 24                                 3D Printing      4
# ...

# %%
# Import necessary libraries
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns  # Make sure you've imported seaborn

# Split the 'Keywords' column by commas and flatten the resulting list of words
keywords_words = [word.strip() for words in df['Keywords'].str.split(',') for word in words]

# Count the occurrences of each word
word_counts = Counter(keywords_words)

# Create a DataFrame from the word counts
word_counts_df = pd.DataFrame.from_dict(word_counts, orient='index', columns=['Count'])
word_counts_df = word_counts_df.reset_index().rename(columns={'index': 'Word'})

# Sort the DataFrame by count in descending order
word_counts_df = word_counts_df.sort_values(by='Count', ascending=False)

# Display the top 10 most common words and their counts
top_10_words = word_counts_df.head(10)
print("Top 10 Most Common Words in Keywords:")
print(top_10_words)

# Create a bar plot to visualize the most common words
plt.figure(figsize=(12, 6))
sns.barplot(x='Count', y='Word', data=top_10_words, palette='viridis')
plt.xlabel('Count')
plt.ylabel('Word')
plt.title('Top 10 Most Common Words in Keywords')
plt.show()
# Out:
# Top 10 Most Common Words in Keywords:
#                      Word  Count
# 151             satellite     17
# 1            space launch     15
# 240    propulsion systems     15
# 195     satellite imagery     14
# 4        space technology     12
# 54      satellite imaging     12
# 201            spacecraft     11
# 23              aerospace     11
# 165      satellite system      9
# 47   aerospace technology      7
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\hp\Desktop\SDAAS-Market-Analysis\env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt


# Count the occurrences of each business status
business_status_counts = df['Business Status'].value_counts()

# Create a pie chart
plt.figure(figsize=(12,12))
plt.pie(business_status_counts, labels=business_status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Business Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Create a legend
plt.legend(title="Business Status", labels=business_status_counts.index, loc="upper right")

# Show the pie chart with the legend
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt


# Group the data by 'Year Founded' and calculate the mean valuation for each year
yearly_valuation = df.groupby('Year Founded')['Last Known Valuation (M)'].mean().reset_index()

# Create a line plot to visualize the valuation of companies for each year
plt.figure(figsize=(12, 6))
plt.plot(yearly_valuation['Year Founded'], yearly_valuation['Last Known Valuation (M)'], marker='o')
plt.xlabel('Year Founded')
plt.ylabel('Mean Valuation (Million $)')
plt.title('Mean Valuation of Companies for Each Year Founded')
plt.grid(True)
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt


# Filter the data for companies founded between 2010 and 2020
filtered_df = df[(df['Year Founded'] >= 2010) & (df['Year Founded'] <= 2020)]

# Group the filtered data by 'Year Founded' and calculate the total valuation for each year
yearly_total_valuation = filtered_df.groupby('Year Founded')['Last Known Valuation (M)'].sum().reset_index()

# Create a cumulative total valuation plot for the years 2010-2020
plt.figure(figsize=(12, 6))
plt.plot(yearly_total_valuation['Year Founded'], yearly_total_valuation['Last Known Valuation (M)'].cumsum(), marker='o')
plt.xlabel('Year Founded')
plt.ylabel('Cumulative Total Valuation (Million $)')
plt.title('Cumulative Total Valuation of Companies (2010-2020)')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Filter the data for companies founded between 2010 and 2020 and remove rows with empty "Keywords"
filtered_df = df[(df['Year Founded'] >= 2010) & (df['Year Founded'] <= 2020) & (~df['Keywords'].isna())]

# Initialize a dictionary to store the most common keyword for each year
most_common_keywords_by_year = {}

# Iterate through each year and find the most common keyword
for year in range(2010, 2021):
    year_df = filtered_df[filtered_df['Year Founded'] == year]
    keywords = year_df['Keywords'].str.split(',').explode().str.strip()
    
    # Check if there are any keywords for the current year
    if not keywords.empty:
        most_common_keyword = keywords.value_counts().idxmax()
        most_common_keywords_by_year[year] = most_common_keyword

# Create a DataFrame from the most common keywords by year
keywords_df = pd.DataFrame.from_dict(most_common_keywords_by_year, orient='index', columns=['Most Common Keyword'])
keywords_df = keywords_df.reset_index().rename(columns={'index': 'Year'})

# Sort the DataFrame by year
keywords_df = keywords_df.sort_values(by='Year')

# Create a bar plot to visualize the most common keyword by year
plt.figure(figsize=(12, 6))
plt.bar(keywords_df['Year'], keywords_df['Most Common Keyword'])
plt.xlabel('Year Founded')
plt.ylabel('Most Common Keyword')
plt.title('Satelite Data by Year (2010-2020)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
